# %% [markdown]
# **Wine Prediction**

# %% [markdown]
# **Get Understanding about Data set**

# %% [markdown]
# Wine data has fifteen variables to understand the wine prediction

# %% [markdown]
# **Import Library**

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# **Import CVS as DataFrame**

# %%
df = pd.read_csv(r'https://github.com/YBI-Foundation/Dataset/raw/main/Wine.csv')

# %% [markdown]
# **Get the First Five Rows of Dataframe**

# %%
df.head()
# Out:
#    class_label class_name  alcohol  malic_acid   ash  alcalinity_of_ash  \
# 0            1     Barolo    14.23        1.71  2.43               15.6
# 1            1     Barolo    13.20        1.78  2.14               11.2
# 2            1     Barolo    13.16        2.36  2.67               18.6
# 3            1     Barolo    14.37        1.95  2.50               16.8
# 4            1     Barolo    13.24        2.59  2.87               21.0
#
#    magnesium  total_phenols  flavanoids  nonflavanoid_phenols  \
# 0        127           2.80        3.06                  0.28
# 1        100           2.65        2.76                  0.26
# 2        101           2.80        3.24                  0.30
# 3        113           3.85        3.49                  0.24
# 4        118           2.80        2.69                  0.39
#
#    proanthocyanins  color_intensity   hue  od280  proline
# 0             2.29             5.64  1.04   3.92     1065
# ...

# %% [markdown]
# **Get Information of DataFrame**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   class_label           178 non-null    int64
#  1   class_name            178 non-null    object
#  2   alcohol               178 non-null    float64
#  3   malic_acid            178 non-null    float64
#  4   ash                   178 non-null    float64
#  5   alcalinity_of_ash     178 non-null    float64
#  6   magnesium             178 non-null    int64
#  7   total_phenols         178 non-null    float64
#  8   flavanoids            178 non-null    float64
#  9   nonflavanoid_phenols  178 non-null    float64
#  10  proanthocyanins       178 non-null    float64
#  11  color_intensity       178 non-null    float64
#  12  hue                   178 non-null    float64
#  13  od280                 178 non-null    float64
# ...

# %% [markdown]
# **Get the Summary Statistics**

# %%
df.describe()
# Out:
#        class_label     alcohol  malic_acid         ash  alcalinity_of_ash  \
# count   178.000000  178.000000  178.000000  178.000000         178.000000
# mean      1.938202   13.000618    2.336348    2.366517          19.494944
# std       0.775035    0.811827    1.117146    0.274344           3.339564
# min       1.000000   11.030000    0.740000    1.360000          10.600000
# 25%       1.000000   12.362500    1.602500    2.210000          17.200000
# 50%       2.000000   13.050000    1.865000    2.360000          19.500000
# 75%       3.000000   13.677500    3.082500    2.557500          21.500000
# max       3.000000   14.830000    5.800000    3.230000          30.000000
#
#         magnesium  total_phenols  flavanoids  nonflavanoid_phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %% [markdown]
# **Get Column Names**

# %%
df.columns
# Out:
# Index(['class_label', 'class_name', 'alcohol', 'malic_acid', 'ash',
#        'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids',
#        'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue',
#        'od280', 'proline'],
#       dtype='object')

# %% [markdown]
# **Get Shape of DataFrame**

# %%
df.shape
# Out:
# (178, 15)

# %% [markdown]
# **Define y and X**

# %%
df.columns
# Out:
# Index(['class_label', 'class_name', 'alcohol', 'malic_acid', 'ash',
#        'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids',
#        'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue',
#        'od280', 'proline'],
#       dtype='object')

# %%
y = df['proline']

# %%
X = df.drop(['class_label', 'hue',
       'od280', 'proline'], axis=1)

# %%
X.shape
# Out:
# (178, 11)

# %%
X
# Out:
#     class_name  alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  \
# 0       Barolo    14.23        1.71  2.43               15.6        127
# 1       Barolo    13.20        1.78  2.14               11.2        100
# 2       Barolo    13.16        2.36  2.67               18.6        101
# 3       Barolo    14.37        1.95  2.50               16.8        113
# 4       Barolo    13.24        2.59  2.87               21.0        118
# ..         ...      ...         ...   ...                ...        ...
# 173    Barbera    13.71        5.65  2.45               20.5         95
# 174    Barbera    13.40        3.91  2.48               23.0        102
# 175    Barbera    13.27        4.28  2.26               20.0        120
# 176    Barbera    13.17        2.59  2.37               20.0        120
# 177    Barbera    14.13        4.10  2.74               24.5         96
#
#      total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# ...

# %%
df['proline'].value_counts()
# Out:
# 680     5
# 520     5
# 625     4
# 750     4
# 630     4
#        ..
# 1265    1
# 1260    1
# 1080    1
# 885     1
# 840     1
# Name: proline, Length: 121, dtype: int64

# %%
df.groupby('proline').mean()
# Out:
# <ipython-input-15-336798fe3600>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('proline').mean()
#          class_label  alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  \
# proline
# 278              2.0    12.00        0.92  2.00               19.0       86.0
# 290              2.0    12.29        2.83  2.22               18.0       88.0
# 312              2.0    12.22        1.29  1.94               19.0       92.0
# 315              2.0    12.42        2.55  2.27               22.0       90.0
# 325              2.0    12.52        2.43  2.17               21.0       88.0
# ...              ...      ...         ...   ...                ...        ...
# 1480             1.0    14.37        1.95  2.50               16.8      113.0
# ...

# %%
y.shape
# Out:
# (178,)

# %%
y
# Out:
# 0      1065
# 1      1050
# 2      1185
# 3      1480
# 4       735
#        ...
# 173     740
# 174     750
# 175     835
# 176     840
# 177     560
# Name: proline, Length: 178, dtype: int64

# %% [markdown]
# **Get Train Test Split**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.7, random_state=2529)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((124, 11), (54, 11), (124,), (54,))
